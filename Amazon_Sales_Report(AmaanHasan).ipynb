# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Importing the Dataset***

# %%
df = pd.read_csv('C:/Users/AMAAN/OneDrive/Desktop/Python reso/Amazon Sale Report up.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %% [markdown]
# ***Dropping the Unnecessary Columns***

# %%
df = df.drop(['New', 'PendingS', 'fulfilled-by'], axis=1)

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# ***Checking for NULL values***

# %%
df.isnull()
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel  \
# 0       False     False  False   False       False          False
# 1       False     False  False   False       False          False
# 2       False     False  False   False       False          False
# 3       False     False  False   False       False          False
# 4       False     False  False   False       False          False
# ...       ...       ...    ...     ...         ...            ...
# 128971  False     False  False   False       False          False
# 128972  False     False  False   False       False          False
# 128973  False     False  False   False       False          False
# 128974  False     False  False   False       False          False
# 128975  False     False  False   False       False          False
#
#         ship-service-level  Category   Size  Courier Status    Qty  currency  \
# 0                    False     False  False           False  False     False
# ...

# %%
df.isnull().sum()
# Out:
# index                    0
# Order ID                 0
# Date                     0
# Status                   0
# Fulfilment               0
# Sales Channel            0
# ship-service-level       0
# Category                 0
# Size                     0
# Courier Status           0
# Qty                      0
# currency              7800
# Amount                7800
# ship-city               35
# ship-state              35
# ship-postal-code        35
# ship-country            35
# B2B                      0
# dtype: int64

# %%
df.shape
# Out:
# (128976, 18)

# %% [markdown]
# ***Dropping Rows with NULL values***

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (121143, 18)

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# dtype: int64

# %% [markdown]
# ***Changing Data Type***

# %%
df['ship-postal-code'] = df['ship-postal-code'].astype('int')

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# ***General Overview of Dataset***

# %%
df.describe(include = 'object')
# Out:
#                    Order ID   Status Fulfilment Sales Channel  \
# count                121143   121143     121143        121143
# unique               112861       12          2             1
# top     171-5057375-2831560  Shipped     Amazon     Amazon.in
# freq                     12    77589      83629        121143
#
#        ship-service-level Category    Size Courier Status currency  ship-city  \
# count              121143   121143  121143         121143   121143     121143
# unique                  2        9      11              3        1       8697
# top             Expedited  T-shirt       M        Shipped      INR  BENGALURU
# freq                82713    47038   20965         109458   121143      10675
#
#          ship-state ship-country
# count        121143       121143
# unique           68            1
# top     MAHARASHTRA           IN
# freq          21084       121143

# %% [markdown]
# ***Insight 1 : Most popular Size is Medium***

# %%
ax = sns.countplot(x='Size', hue='Size', data = df, palette="deep")
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ***Insight 2 : Most Popular Product is T-Shirt***

# %%
pivot_table = df.pivot_table(index='Category', columns='ship-country', values='Qty', aggfunc='sum', fill_value=0)

plt.figure(figsize=(12, 8))  # Adjust figure size as needed
sns.heatmap(pivot_table, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5)
plt.title('Qty')
plt.xlabel('ship-country')
plt.ylabel('Category')
plt.show()

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# ***Insight 3 : Month with Highest Average sales***

# %%
# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# Create a new column 'month' with the month names
df['month'] = df['Date'].dt.month_name()

# Calculate the average amount sold per month
avg_amount_per_month = df.groupby('month')['Amount'].mean()

# Sort by calendar month order if needed
month_order = ["January", "February", "March", "April", "May", "June", 
               "July", "August", "September", "October", "November", "December"]
avg_amount_per_month = avg_amount_per_month.reindex(month_order)

# Plot the line chart
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(avg_amount_per_month.index, avg_amount_per_month.values, marker='o', linestyle='-', color='b')
plt.title('Average Amount Sold per Month')
plt.xlabel('Month')
plt.ylabel('Average Amount Sold')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ***Dropping Unnecessary Columns***

# %%
df = df.drop(['date_category'], axis=1)

# %%
df.head()
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# ***Insight 4 : Analysis of Fulfilment type along with status of delivery***

# %%
import matplotlib.pyplot as plt

# Count occurrences of each Fulfilment and Status combination
status_fulfilment_counts = df.groupby(['Fulfilment', 'Status']).size().unstack()

# Plot a stacked bar chart
status_fulfilment_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap="Set1")
plt.title('Distribution of Status by Fulfilment Type')
plt.xlabel('Fulfilment')
plt.ylabel('Count')
plt.legend(title='Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ***Insight 5 : State with the most number of orders***

# %%
# Calculate the total quantity shipped per state
quantity_per_state = df.groupby('ship-state')['Qty'].sum().sort_values(ascending=False)

# Plot the bar plot
plt.figure(figsize=(20, 6))
sns.barplot(x=quantity_per_state.index, y=quantity_per_state.values, palette="Set2")
plt.title('Total Quantity Shipped per State')
plt.xlabel('ship-state')
plt.ylabel('Qty')
plt.xticks(rotation=90, ha='right')
plt.show()
# Out:
# C:\Users\AMAAN\AppData\Local\Temp\ipykernel_15276\3994455612.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=quantity_per_state.index, y=quantity_per_state.values, palette="Set2")
